# %% [markdown]
# <a href="https://colab.research.google.com/github/Marvin2798/roboreviews-project-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import libraries

# %%
import os
import re
import pandas as pd
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline, Trainer, TrainingArguments

import nltk
nltk.download('stopwords')
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Load data

# %%
dataset_directory = "/root/.cache/kagglehub/datasets/datafiniti/consumer-reviews-of-amazon-products/versions/5/"
filenames = [
    "/content/archive (1).zip",
    "/content/archive (2).zip",
    "/content/archive (3).zip"
]

dataframes = []
for file in filenames:
    file_path = os.path.join(dataset_directory, file)
    if os.path.exists(file_path):
        df = pd.read_csv(file_path, encoding='utf-8')
        dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True).drop_duplicates()
print("Combined Dataset Info:")
print(combined_df.info())
combined_df.to_csv("combined_dataset.csv", index=False)
# Out:
# <ipython-input-6-828c31b53ffe>:13: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# Combined Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67897 entries, 0 to 67991
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    67897 non-null  object
#  1   dateAdded             33237 non-null  object
#  2   dateUpdated           33237 non-null  object
#  3   name                  61137 non-null  object
#  4   asins                 67895 non-null  object
#  5   brand                 67897 non-null  object
#  6   categories            67897 non-null  object
#  7   primaryCategories     33237 non-null  object
#  8   imageURLs             33237 non-null  object
#  9   keys                  67897 non-null  object
#  10  manufacturer          67897 non-null  object
#  11  manufacturerNumber    33237 non-null  object
#  12  reviews.date          67858 non-null  object
#  13  reviews.dateSeen      67897 non-null  object
#  14  reviews.didPurchase   10 non-null     object
#  15  reviews.doRecommend   55057 non-null  object
#  16  reviews.id            71 non-null     float64
#  17  reviews.numHelpful    55151 non-null  float64
#  18  reviews.rating        67864 non-null  float64
#  19  reviews.sourceURLs    67897 non-null  object
#  20  reviews.text          67896 non-null  object
#  21  reviews.title         67878 non-null  object
#  22  reviews.username      67884 non-null  object
#  23  sourceURLs            33237 non-null  object
#  24  reviews.dateAdded     25083 non-null  object
#  25  reviews.userCity      0 non-null      float64
#  26  reviews.userProvince  0 non-null      float64
# dtypes: float64(5), object(22)
# memory usage: 14.5+ MB
# None

# %% [markdown]
# Data preprocessing

# %%
keywords = ['smart speaker', 'Alexa', 'Siri', 'Google Home', 'Bose', 'Sonos', 'Bluetooth Speaker']
smart_speakers = combined_df[combined_df.apply(
    lambda row: row.astype(str).str.contains('|'.join(keywords), case=False, na=False).any(),
    axis=1
)].drop_duplicates()

print("Filtered Smart Speaker Reviews:")
print(smart_speakers.head())
smart_speakers.to_csv("smart_speaker_reviews.csv", index=False)
# Out:
# Filtered Smart Speaker Reviews:
#                         id             dateAdded           dateUpdated  \
# 352   AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 677   AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 989   AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1186  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1267  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                    name  \
# 352   AmazonBasics AAA Performance Alkaline Batterie...
# 677   AmazonBasics AAA Performance Alkaline Batterie...
# 989   AmazonBasics AAA Performance Alkaline Batterie...
# 1186  AmazonBasics AAA Performance Alkaline Batterie...
# 1267  AmazonBasics AAA Performance Alkaline Batterie...
#
#                       asins         brand  \
# 352   B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 677   B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 989   B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 1186  B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 1267  B00QWO9P0O,B00LH3DMUO  Amazonbasics
#
#                                              categories primaryCategories  \
# 352   AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 677   AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 989   AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1186  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1267  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
#
#                                               imageURLs  \
# 352   https://images-na.ssl-images-amazon.com/images...
# 677   https://images-na.ssl-images-amazon.com/images...
# 989   https://images-na.ssl-images-amazon.com/images...
# 1186  https://images-na.ssl-images-amazon.com/images...
# 1267  https://images-na.ssl-images-amazon.com/images...
#
#                                                    keys  ...  \
# 352   amazonbasics/hl002619,amazonbasicsaaaperforman...  ...
# 677   amazonbasics/hl002619,amazonbasicsaaaperforman...  ...
# 989   amazonbasics/hl002619,amazonbasicsaaaperforman...  ...
# 1186  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...
# 1267  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...
#
#      reviews.numHelpful reviews.rating  \
# 352                 NaN            5.0
# 677                 NaN            5.0
# 989                 NaN            1.0
# 1186                NaN            5.0
# 1267                NaN            5.0
#
#                                      reviews.sourceURLs  \
# 352   https://www.amazon.com/product-reviews/B00QWO9...
# 677   https://www.amazon.com/product-reviews/B00QWO9...
# 989   https://www.amazon.com/product-reviews/B00QWO9...
# 1186  https://www.amazon.com/product-reviews/B00QWO9...
# 1267  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                            reviews.text  \
# 352   The batteries arrived in a timely manner. I wa...
# 677   I am highly satisfied with these batteries. I ...
# 989   Worst batteries for photographers. I'm sure th...
# 1186                Work great fast delivery good price
# 1267  Amazing price and with my kids, I feel like Al...
#
#                                reviews.title      reviews.username  \
# 352                   Arrived in Record Time   ByMaryellen Honkomp
# 677   Better than most name brand batteries!                ByRCAL
# 989      DON'T BUY if you are a photographer  ByAlexandrea Thomsen
# 1186           Fine purchase Good Alexa deal          ByAliciagogo
# 1267                              Five Stars         ByChad Moroni
#
#                                              sourceURLs  reviews.dateAdded  \
# 352   https://www.barcodable.com/upc/841710106442,ht...                NaN
# 677   https://www.barcodable.com/upc/841710106442,ht...                NaN
# 989   https://www.barcodable.com/upc/841710106442,ht...                NaN
# 1186  https://www.barcodable.com/upc/841710106442,ht...                NaN
# 1267  https://www.barcodable.com/upc/841710106442,ht...                NaN
#
#       reviews.userCity reviews.userProvince
# 352                NaN                  NaN
# 677                NaN                  NaN
# 989                NaN                  NaN
# 1186               NaN                  NaN
# 1267               NaN                  NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# data cleaning

# %%
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    text = ' '.join([word for word in text.split() if word not in stopwords.words('english')])
    return text

smart_speakers['cleaned_text'] = smart_speakers['reviews.text'].apply(clean_text)

# %%
smart_speakers['cleaned_text'] = smart_speakers['reviews.text'].apply(clean_text)

smart_speakers.to_csv("smart_speaker_reviews_cleaned.csv", index=False)

print("Smart Speaker Reviews with Cleaned Text:")
print(smart_speakers.head())
# Out:
# Smart Speaker Reviews with Cleaned Text:
#                         id             dateAdded           dateUpdated  \
# 352   AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 677   AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 989   AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1186  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1267  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                    name  \
# 352   AmazonBasics AAA Performance Alkaline Batterie...
# 677   AmazonBasics AAA Performance Alkaline Batterie...
# 989   AmazonBasics AAA Performance Alkaline Batterie...
# 1186  AmazonBasics AAA Performance Alkaline Batterie...
# 1267  AmazonBasics AAA Performance Alkaline Batterie...
#
#                       asins         brand  \
# 352   B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 677   B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 989   B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 1186  B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 1267  B00QWO9P0O,B00LH3DMUO  Amazonbasics
#
#                                              categories primaryCategories  \
# 352   AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 677   AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 989   AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1186  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1267  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
#
#                                               imageURLs  \
# 352   https://images-na.ssl-images-amazon.com/images...
# 677   https://images-na.ssl-images-amazon.com/images...
# 989   https://images-na.ssl-images-amazon.com/images...
# 1186  https://images-na.ssl-images-amazon.com/images...
# 1267  https://images-na.ssl-images-amazon.com/images...
#
#                                                    keys  ... reviews.rating  \
# 352   amazonbasics/hl002619,amazonbasicsaaaperforman...  ...            5.0
# 677   amazonbasics/hl002619,amazonbasicsaaaperforman...  ...            5.0
# 989   amazonbasics/hl002619,amazonbasicsaaaperforman...  ...            1.0
# 1186  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...            5.0
# 1267  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...            5.0
#
#                                      reviews.sourceURLs  \
# 352   https://www.amazon.com/product-reviews/B00QWO9...
# 677   https://www.amazon.com/product-reviews/B00QWO9...
# 989   https://www.amazon.com/product-reviews/B00QWO9...
# 1186  https://www.amazon.com/product-reviews/B00QWO9...
# 1267  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                            reviews.text  \
# 352   The batteries arrived in a timely manner. I wa...
# 677   I am highly satisfied with these batteries. I ...
# 989   Worst batteries for photographers. I'm sure th...
# 1186                Work great fast delivery good price
# 1267  Amazing price and with my kids, I feel like Al...
#
#                                reviews.title      reviews.username  \
# 352                   Arrived in Record Time   ByMaryellen Honkomp
# 677   Better than most name brand batteries!                ByRCAL
# 989      DON'T BUY if you are a photographer  ByAlexandrea Thomsen
# 1186           Fine purchase Good Alexa deal          ByAliciagogo
# 1267                              Five Stars         ByChad Moroni
#
#                                              sourceURLs  reviews.dateAdded  \
# 352   https://www.barcodable.com/upc/841710106442,ht...                NaN
# 677   https://www.barcodable.com/upc/841710106442,ht...                NaN
# 989   https://www.barcodable.com/upc/841710106442,ht...                NaN
# 1186  https://www.barcodable.com/upc/841710106442,ht...                NaN
# 1267  https://www.barcodable.com/upc/841710106442,ht...                NaN
#
#       reviews.userCity  reviews.userProvince  \
# 352                NaN                   NaN
# 677                NaN                   NaN
# 989                NaN                   NaN
# 1186               NaN                   NaN
# 1267               NaN                   NaN
#
#                                            cleaned_text
# 352   batteries arrived timely manner need battery w...
# 677   highly satisfied batteries mainly use bose noi...
# 989   worst batteries photographers im sure might fi...
# 1186                work great fast delivery good price
# 1267  amazing price kids feel like alexa ordering month
#
# [5 rows x 28 columns]

# %% [markdown]
# Sentiment Labels

# %%
# 3. Create Sentiment Labels (based on ratings if available)
def assign_sentiment(rating):
    if rating >= 4:
        return 'positive'
    elif rating == 3:
        return 'neutral'
    else:
        return 'negative'

if 'reviews.rating' in df.columns:
    df['sentiment'] = df['reviews.rating'].apply(assign_sentiment)

# Check if the sentiment labels are assigned correctly
print(df['sentiment'].value_counts())
# Out:
# sentiment
# positive    32316
# neutral      1499
# negative      845
# Name: count, dtype: int64

# %%
print(value_counts())

# %% [markdown]
# Split Data

# %%
train, test = train_test_split(smart_speakers, test_size=0.2, random_state=42)
print("Training Set Size:", train.shape)
print("Testing Set Size:", test.shape)
# Out:
# Training Set Size: (9189, 29)
# Testing Set Size: (2298, 29)

# %% [markdown]
# Sentiment classification

# %%
# Initialize HuggingFace tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=3)

# Tokenize the training and testing data
train_encodings = tokenizer(list(train['cleaned_text']), truncation=True, padding=True, max_length=256)
test_encodings = tokenizer(list(test['cleaned_text']), truncation=True, padding=True, max_length=256)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# prompt: inference from model on the train_encondings

import numpy as np

# Assuming 'model' is your trained sentiment classification model and 'train_encodings' are the tokenized training data.

# Create a pipeline for inference
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Perform inference on a subset of the training data for demonstration (adjust as needed)
sample_size = min(len(train_encodings['input_ids']), 10)  # Infer on the first 10 samples
train_texts = list(train['cleaned_text'])[10:45]
results = classifier(train_texts)

# Print the results
for i, result in enumerate(results):
  print(f"Text: {train_texts[i]}")
  print(f"Predicted Label: {result['label']}, Score: {result['score']}")
# Out:
# Text: one good item bought 2017 thanksgiving deals
# Predicted Label: LABEL_0, Score: 0.38369858264923096
# Text: finally decided try echo system months months debate purchased echo plus echo dot plus easily handles main two floors dot handles upstairs pluss speakers incredible size agree made right choice get plus
# Predicted Label: LABEL_0, Score: 0.3760433495044708
# Text: alexa really works sceptical first part family im cooking three different things go microwave stovetop outside grill need pulled heat different times problem ask alexa set timers item go along awesome time watch movie alexa turn living room lights lights dim confirms ok nice little bit warm alexa set temperature 69 airconditioner comes magical nephew like cooking alexa open dominos asks order choice within seconds dominos order paid arrives time truly one coolest devices ever purchased almost forgot anytime want hear piece music loved past call pull right listen near bose quality sound magic
# Predicted Label: LABEL_0, Score: 0.3701472282409668
# Text: love new alexa sooo easy use many apps program best purchase ive made long time
# Predicted Label: LABEL_0, Score: 0.36831799149513245
# Text: great tablet grandson loves play games tube
# Predicted Label: LABEL_0, Score: 0.38251978158950806
# Text: product amazing helpful update new skills time think one favorite tech products ever used
# Predicted Label: LABEL_0, Score: 0.36929094791412354
# Text: bought tablet 8 year old holding good loves enjoys playimg games able get internet
# Predicted Label: LABEL_0, Score: 0.3768463134765625
# Text: would like alexa help f8nd stuff youtube apps instead typing though awesome investment
# Predicted Label: LABEL_0, Score: 0.36203092336654663
# Text: got birthday love love resolution size blue light setting thinking buying one four year old nephew christmas present need buy sleeve
# Predicted Label: LABEL_0, Score: 0.3784528970718384
# Text: two echo dots wanted something portable times im near two devices home also needed speaker thought id try echo tap choose press activate enable handsfree respond like echo dot sound amazing little thing love charging dock dealing trying plug sit charging dock youre good
# Predicted Label: LABEL_0, Score: 0.3591574430465698
# Text: bought fire hd 8 tablet wife doesnt like using computers avoids smartphones new tablet big hit uses play games stream movies radio programs use everything else reading news checking email online shopping etc easy set even easier use plenty speed capacity everything want
# Predicted Label: LABEL_0, Score: 0.35809874534606934
# Text: love alexa music books facts gameschristmas stories giving gifts also
# Predicted Label: LABEL_0, Score: 0.3841836154460907
# Text: bought display echo turning voicecast routes information tablet voice reaponse exactly hoped would price right
# Predicted Label: LABEL_0, Score: 0.3726412057876587
# Text: theres lot features getting started tap glad made purchase
# Predicted Label: LABEL_0, Score: 0.3738412857055664
# Text: im super happy glad made purchase
# Predicted Label: LABEL_0, Score: 0.3750905692577362
# Text: read reviews purchased item far good handydandy case found sale 999 time works well
# Predicted Label: LABEL_0, Score: 0.37920472025871277
# Text: one best products ever created love alexa
# Predicted Label: LABEL_0, Score: 0.37700900435447693
# Text: cant blue tooth speaker without slecting listthere list
# Predicted Label: LABEL_0, Score: 0.3713555335998535
# Text: love amazon echo show however wish alexa knew little bit
# Predicted Label: LABEL_0, Score: 0.37678462266921997
# Text: tin sounding bass sounds terrible bought bose sound link amazon dot hook
# Predicted Label: LABEL_0, Score: 0.3842673599720001
# Text: got dad easy use loves good stepping stone future producs
# Predicted Label: LABEL_0, Score: 0.38743507862091064
# Text: alexa helps much kitchen keep entertained making smartthings work together
# Predicted Label: LABEL_0, Score: 0.3738817870616913
# Text: 2 echos one living room upstairs alexa play whatever music ask tell weather joke timer alarm clock keeps grocery list notify someone choosing emergency home companion elderly person even keep paraplegic company using voice hundreds apps download enables alexa command use echo everyday listened favorite songs past well current hits andor radio stations become welcome addition home buy one wont regret
# Predicted Label: LABEL_0, Score: 0.37177732586860657
# Text: love keeps getting better time
# Predicted Label: LABEL_0, Score: 0.36283737421035767
# Text: bought gift loves entertaining wonderful volume lots fun
# Predicted Label: LABEL_0, Score: 0.3739772140979767
# Text: wifes ipad mini issues wore flat wanted get another one want spend money new ipad gave one try bb reward zone got 100ish 32gb memoryto clear level ipad mini designed technical specs quite good 100ish dollars reputable company bad first thing note come ability download google play store get around side loading google plenty websites tell easilymy wife burning tablet really likes let go shortcomings vs ipad mini overall likes goodso wanting inexpensive tablet reliable company try fire tablet
# Predicted Label: LABEL_0, Score: 0.3631354570388794
# Text: echo better expected speaker plays music well hook spotify alexa app tell want hear
# Predicted Label: LABEL_0, Score: 0.36911699175834656
# Text: pretty cool kids love always adding things grocery list didnt want
# Predicted Label: LABEL_0, Score: 0.37276947498321533
# Text: got gift boyfriend loves convenient easy use
# Predicted Label: LABEL_0, Score: 0.3760010302066803
# Text: overall enjoy new echo tower speaker quality sonos bose speakers convenience able ask alexa play song find style music tell weather traffic running door make quality kids love asking rap tell joke look forward syncing alexa iot items make controls hands free
# Predicted Label: LABEL_0, Score: 0.36502909660339355
# Text: bought son absolutely loves
# Predicted Label: LABEL_0, Score: 0.38471150398254395
# Text: great tablet grandson plenty storage favorite games books also enjoy parental settings see everything set time limits overall great buyand pricing way awesome
# Predicted Label: LABEL_0, Score: 0.36573487520217896
# Text: works great looking forward purchase diffrent rooms house
# Predicted Label: LABEL_0, Score: 0.37907201051712036
# Text: im good electronics worried learning use kindle fire problems navigation device feel also fast expecting sluggish think great beginner great bargain
# Predicted Label: LABEL_0, Score: 0.3655157685279846
# Text: skeptical first lot research vanity purchase turned one function home devices timer kitchen done quick weather check done order something amazon done throwing party need tunes great speaker done alexa continue get better echo gets smarter use
# Predicted Label: LABEL_0, Score: 0.37007471919059753

# %%
# Create a balanced dataset (where neutral size = positive size = negative size)
# Fine tune the model (loss and the accuracy, 3 epoch first and increase if necessary)
# Save this model and MAKE SURE you download it!!! You dont want to lose it
# Evaluate (ie scikitlearn classification report)
# Out:
# {'LABEL_0'}

# %%
train['sentiment'][10:45]
# Out:
# 29799    positive
# 29453    positive
# 60792    positive
# 56108    positive
# 20680    positive
# 56028    positive
# 21109     neutral
# 64587    positive
# 26789    positive
# 31488    positive
# 28276    positive
# 58476    positive
# 27084    positive
# 62532    positive
# 21005    positive
# 27929    positive
# 61731    positive
# 59529    positive
# 28977    positive
# 12752    negative
# 28205    positive
# 56638    positive
# 59912    positive
# 28880    positive
# 12625    positive
# 20903    positive
# 59076    positive
# 31387    positive
# 22514    positive
# 56955    positive
# 26181    positive
# 19699    positive
# 29768    positive
# 26210    positive
# 61025    positive
# Name: sentiment, dtype: object

# %% [markdown]
# clustering

# %%
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer

sentence_transformer = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = sentence_transformer.encode(smart_speakers['cleaned_text'].tolist())

#TODO : try different n_clusters values -> find the best one using the elbow method / fine tuning
kmeans = KMeans(n_clusters=4, random_state=42)
smart_speakers['cluster'] = kmeans.fit_predict(embeddings)

print(smart_speakers['cluster'].value_counts())


#evaluation
# you need add metrics to evluate yuur clustering
# kmeans = sihluete score (but double check the sikit learn db and other extra metrics in here)
# text = entropy value for the clustering (should be low for the same cluster and hight between clusters)
# buld average representation of the cluster (either with the embdded vector or by chossing the words that are apprearing more frequently)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# cluster
# 2    3532
# 1    3482
# 3    2665
# 0    1808
# Name: count, dtype: int64

# %%
print(smart_speakers['cluster'].unique())
# Out:
# [1 3 0 2]

# %% [markdown]
# verify the data

# %%
print(smart_speakers.columns)
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs',
#        'reviews.dateAdded', 'reviews.userCity', 'reviews.userProvince',
#        'cleaned_text', 'sentiment', 'cluster'],
#       dtype='object')
